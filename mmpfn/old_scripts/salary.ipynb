# %%
import pandas as pd

# %%
path = '/home/wall/works/research/MultiModalPFN/mmpfn/data/salary/train.csv'

# %%
df = pd.read_csv(path)

# %%
df.shape
# Out:
# (19802, 9)

# %%
df
# Out:
#        Unnamed: 0 experience  \
# 0               0    5-7 yrs
# 1               1  10-17 yrs
# 2               2    5-9 yrs
# 3               3   7-10 yrs
# 4               4    1-3 yrs
# ...           ...        ...
# 19797       19797  12-18 yrs
# 19798       19798    0-3 yrs
# 19799       19799   8-13 yrs
# 19800       19800    1-3 yrs
# 19801       19801    2-5 yrs
#
#                                          job_description  \
# 0      Exp: Minimum 5 years;Good understanding of IOC...
# 1      He should have handled a team of atleast 5-6 d...
# 2      Must be an effective communicator (written & s...
# 3      7  -  10 years of overall experience in data e...
# 4      Chartered Accountancy degree or MBA in Finance...
# ...                                                  ...
# 19797                                                NaN
# 19798                                                NaN
# 19799  Annuities Domain experience is mandatory;Work ...
# ...

# %%
df['company_name_encoded'].nunique()
# Out:
# 5035
