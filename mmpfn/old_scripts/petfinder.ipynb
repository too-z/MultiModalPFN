# %%
import pandas as pd

# %%
path = "/home/wall/works/research/MultiModalPFN/mmpfn/data/petfinder/train/train.csv"

# %%
df = pd.read_csv(path)

# %%
df.shape
# Out:
# (14993, 24)

# %%
df.columns
# Out:
# Index(['Type', 'Name', 'Age', 'Breed1', 'Breed2', 'Gender', 'Color1', 'Color2',
#        'Color3', 'MaturitySize', 'FurLength', 'Vaccinated', 'Dewormed',
#        'Sterilized', 'Health', 'Quantity', 'Fee', 'State', 'RescuerID',
#        'VideoAmt', 'Description', 'PetID', 'PhotoAmt', 'AdoptionSpeed'],
#       dtype='object')

# %%
if "AdoptionSpeed" in list(df.columns): print("all")

# %%
for col in df.columns:
    print(col, df[col].nunique(), '/', len(df))
# Out:
# Type 2 / 3972
# Name 2750 / 3972
# Age 71 / 3972
# Breed1 118 / 3972
# Breed2 92 / 3972
# Gender 3 / 3972
# Color1 7 / 3972
# Color2 7 / 3972
# Color3 6 / 3972
# MaturitySize 4 / 3972
# FurLength 3 / 3972
# Vaccinated 3 / 3972
# Dewormed 3 / 3972
# Sterilized 3 / 3972
# Health 3 / 3972
# Quantity 16 / 3972
# Fee 41 / 3972
# State 15 / 3972
# RescuerID 1518 / 3972
# VideoAmt 8 / 3972
# Description 3723 / 3972
# PetID 3972 / 3972
# PhotoAmt 29 / 3972

# %%
df['ImagePath']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['ImagePath']
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#        Type            Name  Age  Breed1  Breed2  Gender  Color1  Color2  \
# 0         2          Nibble    3     299       0       1       1       7
# 1         2     No Name Yet    1     265       0       1       1       2
# 2         1          Brisco    1     307       0       1       2       7
# 3         1            Miko    4     307       0       2       1       2
# 4         1          Hunter    1     307       0       1       1       0
# ...     ...             ...  ...     ...     ...     ...     ...     ...
# 14988     2             NaN    2     266       0       3       1       0
# 14989     2  Serato & Eddie   60     265     264       3       1       4
# 14990     2         Monkies    2     265     266       3       5       6
# 14991     2         Ms Daym    9     266       0       2       4       7
# 14992     1            Fili    1     307     307       1       2       0
#
#        Color3  MaturitySize  ...  Health  Quantity  Fee  State  \
# ...
