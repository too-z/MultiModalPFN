# %%
from __future__ import annotations

from torch.utils.data import random_split

from mmpfn.datasets.petfinder_pawpularity import PawpularityDataset

import os 
import torch 
import numpy as np 
import pandas as pd

from sklearn.metrics import r2_score, root_mean_squared_error
from mmpfn.models.mmpfn import MMPFNRegressor
from mmpfn.models.mmpfn.constants import ModelInterfaceConfig
from mmpfn.models.mmpfn.preprocessing import PreprocessorConfig
from mmpfn.scripts_finetune_mm.finetune_tabpfn_main import fine_tune_mmpfn
# Out:
# /home/wall/works/research/MultiModalPFN/mmpfn/models/dino_v2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /home/wall/works/research/MultiModalPFN/mmpfn/models/dino_v2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /home/wall/works/research/MultiModalPFN/mmpfn/models/dino_v2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"  # for debugging

# %%
data_path = os.path.join(os.getenv('HOME'), "works/research/MultiModalPFN/mmpfn/data/pawpularity")
dataset = PawpularityDataset(data_path)
# _ = dataset.get_images()
_ = dataset.get_embeddings()
# Out:
# Load embeddings from embeddings/pawpularity/pawpularity.pt

# %%
r2_scores = []
for seed in range(5):
    torch.manual_seed(seed)
    train_len = int(len(dataset) * 0.8)
    test_len = len(dataset) - train_len

    train_dataset, test_dataset = random_split(dataset, [train_len, test_len])

    X_train = train_dataset.dataset.x[train_dataset.indices]
    y_train = train_dataset.dataset.y[train_dataset.indices]
    X_test = test_dataset.dataset.x[test_dataset.indices]
    y_test = test_dataset.dataset.y[test_dataset.indices]
    image_train = train_dataset.dataset.embeddings[train_dataset.indices]#.unsqueeze(1)
    image_test = test_dataset.dataset.embeddings[test_dataset.indices]#.unsqueeze(1)
        
    for i in range(X_train.shape[1]):
        col = X_train[:, i]
        col[np.isnan(col)] = np.nanmin(col) - 1
    for i in range(X_test.shape[1]):
        col = X_test[:, i]
        col[np.isnan(col)] = np.nanmin(col) - 1

    torch.cuda.empty_cache()

    save_path_to_fine_tuned_model = "./finetuned_mmpfn_airbnb.ckpt"

    fine_tune_mmpfn(
        # path_to_base_model="auto",
        save_path_to_fine_tuned_model=save_path_to_fine_tuned_model,
        # Finetuning HPs
        time_limit=60,
        finetuning_config={"learning_rate": 0.00001, "batch_size": 1, "max_steps": 100},
        validation_metric="rmse",
        # Input Data
        X_train=pd.DataFrame(X_train),
        image_train=image_train,
        y_train=pd.Series(y_train),
        categorical_features_index=None,
        device="cuda",  # use "cpu" if you don't have a GPU
        task_type="regression",
        # Optional
        show_training_curve=False,  # Shows a final report after finetuning.
        logger_level=0,  # Shows all logs, higher values shows less
        freeze_input=True,  # Freeze the input layers (encoder and y_encoder) during finetuning
        mixer_type='MGM', # MGM MGM+CQAM
        mgm_heads=8,
        cqam_heads=4,
    )

    # disables preprocessing at inference time to match fine-tuning
    no_preprocessing_inference_config = ModelInterfaceConfig(
        FINGERPRINT_FEATURE=False,
        PREPROCESS_TRANSFORMS=[PreprocessorConfig(name='none')]
    )

    # Evaluate on Test Data
    model_finetuned = MMPFNRegressor(
        model_path=save_path_to_fine_tuned_model,
        inference_config=no_preprocessing_inference_config,
        ignore_pretraining_limits=True,
        mixer_type='MGM', # MGM MGM+CQAM
        mgm_heads=8,
        cqam_heads=4,
    )

    clf_finetuned = model_finetuned.fit(X_train, image_train, y_train)
    r2 = root_mean_squared_error(y_test, clf_finetuned.predict(X_test, image_test))
    print("r2 (Finetuned):", r2)
    r2_scores.append(r2)
# Out:
# Fine-tuning Steps:   1%|          | 1/100 [00:00<?, ?it/s][2025-09-12 00:47:08,209] INFO -
# Optimizer step skipped due to NaNs/infs in grad scaling.
# Fine-tuning Steps:   2%|▏         | 2/100 [00:02<04:06,  2.52s/it, Best Val. Loss=0.202, Best Val. Score=-0.202, Training Loss=1.32, Val. Loss=0.202, Patience=50, Utilization=0, Grad Norm=inf][2025-09-12 00:47:10,584] INFO -
# Optimizer step skipped due to NaNs/infs in grad scaling.
# Fine-tuning Steps:  17%|█▋        | 17/100 [00:48<04:14,  3.07s/it, Best Val. Loss=0.2, Best Val. Score=-0.2, Training Loss=0.078, Val. Loss=0.224, Patience=36, Utilization=0, Grad Norm=21.1]  [2025-09-12 00:47:56,509] INFO -
# Optimizer step skipped due to NaNs/infs in grad scaling.
# Fine-tuning Steps: 101it [05:09,  3.09s/it, Best Val. Loss=0.2, Best Val. Score=-0.2, Training Loss=-0.65, Val. Loss=0.211, Patience=-47, Utilization=0, Grad Norm=10.7]
# [2025-09-12 00:52:14,899] INFO - Initial Validation Loss: 0.20205622911453247 Best Validation Loss: 0.19982247054576874 Total Steps: 101 Best Step: 8 Total Time Spent: 310.92487359046936
# r2 (Finetuned): 0.2095202024956909
# Fine-tuning Steps:   1%|          | 1/100 [00:00<?, ?it/s][2025-09-12 00:52:25,815] INFO -
# Optimizer step skipped due to NaNs/infs in grad scaling.
# Fine-tuning Steps:   2%|▏         | 2/100 [00:02<04:52,  2.98s/it, Best Val. Loss=0.205, Best Val. Score=-0.205, Training Loss=1.35, Val. Loss=0.205, Patience=50, Utilization=0, Grad Norm=inf]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 27
#      23 torch.cuda.empty_cache()
#      25 save_path_to_fine_tuned_model = "./finetuned_mmpfn_airbnb.ckpt"
# ---> 27 fine_tune_mmpfn(
#      28     # path_to_base_model="auto",
#      29     save_path_to_fine_tuned_model=save_path_to_fine_tuned_model,
#      30     # Finetuning HPs
#      31     time_limit=60,
#      32     finetuning_config={"learning_rate": 0.00001, "batch_size": 1, "max_steps": 100},
#      33     validation_metric="rmse",
#      34     # Input Data
#      35     X_train=pd.DataFrame(X_train),
#      36     image_train=image_train,
#      37     y_train=pd.Series(y_train),
#      38     categorical_features_index=None,
#      39     device="cuda",  # use "cpu" if you don't have a GPU
#      40     task_type="regression",
#      41     # Optional
#      42     show_training_curve=False,  # Shows a final report after finetuning.
#      43     logger_level=0,  # Shows all logs, higher values shows less
#      44     freeze_input=True,  # Freeze the input layers (encoder and y_encoder) during finetuning
#      45     mixer_type='MGM', # MGM MGM+CQAM
#      46     mgm_heads=8,
#      47     cqam_heads=4,
#      48 )
#      50 # disables preprocessing at inference time to match fine-tuning
#      51 no_preprocessing_inference_config = ModelInterfaceConfig(
#      52     FINGERPRINT_FEATURE=False,
#      53     PREPROCESS_TRANSFORMS=[PreprocessorConfig(name='none')]
#      54 )
#
# File ~/works/research/MultiModalPFN/mmpfn/scripts_finetune_mm/finetune_tabpfn_main.py:395, in fine_tune_mmpfn(mixer_type, mgm_heads, cqam_heads, path_to_base_model, save_path_to_fine_tuned_model, time_limit, finetuning_config, validation_metric, categorical_features_index, task_type, device, y_train, X_train, image_train, use_multiple_gpus, multiple_device_ids, X_val, y_val, random_seed, logger_level, show_training_curve, freeze_input)
#     393 model.train()
#     394 optimizer.train()
# --> 395 step_results = _fine_tune_step(
#     396     batch_X_train=batch_data["X_train"] if "X_train" in batch_data.keys() else None,
#     397     batch_X_test=batch_data["X_test"] if "X_test" in batch_data.keys() else None,
#     398     batch_X_image_train=batch_data["image_train"] if "image_train" in batch_data.keys() else None,
#     399     batch_X_image_test=batch_data["image_test"] if "image_test" in batch_data.keys() else None,
#     400     batch_y_train=batch_data["y_train"],
#     401     batch_y_test=batch_data["y_test"],
#     402     device=device,
#     403     optimizer=optimizer,
#     404     model_forward_fn=model_forward_fn,
#     405     loss_fn=fts.loss_fn,
#     406     gradient_accumulation_steps=gradient_accumulation_steps,
#     407     # Updated by the loop
#     408     model=model,
#     409     scaler=scaler,
#     410     step_with_update=update_now,
#     411 )
#     413 if step_results.optimizer_step_skipped:
#     414     logger.info("\nOptimizer step skipped due to NaNs/infs in grad scaling.")
#
# File ~/works/research/MultiModalPFN/mmpfn/scripts_finetune_mm/finetune_tabpfn_main.py:667, in _fine_tune_step(batch_X_train, batch_X_test, batch_X_image_train, batch_X_image_test, batch_y_train, batch_y_test, device, model, optimizer, model_forward_fn, loss_fn, scaler, step_with_update, gradient_accumulation_steps)
#     664     if gradient_accumulation_steps is not None:
#     665         loss = loss / gradient_accumulation_steps
# --> 667 torch.cuda.empty_cache()
#     668 # Backward, Scaled for Mixed Precision
#     669 scaler.scale(loss).backward()
#
# File ~/anaconda3/envs/mmpfn/lib/python3.10/site-packages/torch/cuda/memory.py:170, in empty_cache()
#     159 r"""Release all unoccupied cached memory currently held by the caching
#     160 allocator so that those can be used in other GPU application and visible in
#     161 `nvidia-smi`.
#    (...)
#     167     more details about GPU memory management.
#     168 """
#     169 if is_initialized():
# --> 170     torch._C._cuda_emptyCache()
#
# KeyboardInterrupt:

# %%
# get mean and std of accuracy scores
mean_r2 = np.mean(r2_scores)
std_r2 = np.std(r2_scores)
print("Mean R2:", mean_r2)
print("Std R2:", std_r2)
