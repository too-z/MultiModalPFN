# %%
from __future__ import annotations

import os 

from torch.utils.data import random_split

from mmpfn.datasets.ol3i import OL3IDataset

import os 
import torch 
import numpy as np 
import pandas as pd

from sklearn.metrics import accuracy_score
from mmpfn.models.mmpfn_v2 import MMPFNClassifier
from mmpfn.models.mmpfn_v2.constants import ModelInterfaceConfig
from mmpfn.models.mmpfn_v2.preprocessing import PreprocessorConfig
from mmpfn.scripts_finetune_mm.finetune_tabpfn_main import fine_tune_tabpfn
# Out:
# /home/wall/works/research/MultiModalPFN/mmpfn/models/dino_v2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /home/wall/works/research/MultiModalPFN/mmpfn/models/dino_v2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /home/wall/works/research/MultiModalPFN/mmpfn/models/dino_v2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
image_type='cls' # patch cls
# data_path = os.path.join(os.getenv('HOME'), "workspace/works/tabular_image/MultiModalPFN/mmpfn/data/ol3i")
data_path = os.path.join(os.getenv('HOME'), "works/research/MultiModalPFN/mmpfn/data/ol3i")

train_dataset = OL3IDataset(data_path=data_path, mode='train')
# _ = train_dataset.get_images()
_ = train_dataset.get_embeddings(image_type=image_type)
test_dataset = OL3IDataset(data_path=data_path, mode='test')
# _ = test_dataset.get_images()
_ = test_dataset.get_embeddings(image_type=image_type)
# Out:
# /home/wall/works/research/MultiModalPFN/mmpfn/datasets/ol3i.py:23: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_csv(os.path.join(data_path, 'clinical_data.csv'))
# Load embeddings from embeddings/ol3i/cls_train.pt
# Load embeddings from embeddings/ol3i/cls_test.pt
# /home/wall/works/research/MultiModalPFN/mmpfn/datasets/ol3i.py:23: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_csv(os.path.join(data_path, 'clinical_data.csv'))

# %%
accuracy_scores = []
for seed in range(5):
    torch.manual_seed(seed)

    X_train = train_dataset.x
    y_train = train_dataset.y
    X_test = test_dataset.x
    y_test = test_dataset.y
    image_train = train_dataset.embeddings
    image_test = test_dataset.embeddings

    if image_type == 'cls':
        image_train = image_train.unsqueeze(1)
        image_test = image_test.unsqueeze(1)
        
    for i in range(X_train.shape[1]):
        col = X_train[:, i]
        col[np.isnan(col)] = np.nanmin(col) - 1
    for i in range(X_test.shape[1]):
        col = X_test[:, i]
        col[np.isnan(col)] = np.nanmin(col) - 1

    torch.cuda.empty_cache()

    save_path_to_fine_tuned_model = "./finetuned_mmpfn_ol3i.ckpt"
    
    fine_tune_tabpfn(
        # path_to_base_model="auto",
        save_path_to_fine_tuned_model=save_path_to_fine_tuned_model,
        # Finetuning HPs
        time_limit=60,
        finetuning_config={"learning_rate": 0.00001, "batch_size": 1, "max_steps": 100},
        validation_metric="log_loss",
        # Input Data
        X_train=pd.DataFrame(X_train),
        image_train=image_train,
        y_train=pd.Series(y_train),
        categorical_features_index=None,
        device="cuda",  # use "cpu" if you don't have a GPU
        task_type="multiclass",
        # Optional
        show_training_curve=False,  # Shows a final report after finetuning.
        logger_level=0,  # Shows all logs, higher values shows less
        freeze_input=True,  # Freeze the input layers (encoder and y_encoder) during finetuning
        mixer_type='MGM' # MGM MGM+CQAM
    )

    # disables preprocessing at inference time to match fine-tuning
    no_preprocessing_inference_config = ModelInterfaceConfig(
        FINGERPRINT_FEATURE=False,
        PREPROCESS_TRANSFORMS=[PreprocessorConfig(name='none')]
    )

    # Evaluate on Test Data
    model_finetuned = MMPFNClassifier(
        model_path=save_path_to_fine_tuned_model,
        inference_config=no_preprocessing_inference_config,
        ignore_pretraining_limits=True,
        mixer_type='MGM' # no_append token_append split_append multihead
    )

    clf_finetuned = model_finetuned.fit(X_train, image_train, y_train)
    acc_score = accuracy_score(y_test, clf_finetuned.predict(X_test, image_test))
    print("accuracy_score (Finetuned):", acc_score)
    accuracy_scores.append(acc_score)
# Out:
# Fine-tuning Steps:   1%|          | 1/100 [02:27<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[4], line 27
#      23 torch.cuda.empty_cache()
#      25 save_path_to_fine_tuned_model = "./finetuned_mmpfn_ol3i.ckpt"
# ---> 27 fine_tune_tabpfn(
#      28     # path_to_base_model="auto",
#      29     save_path_to_fine_tuned_model=save_path_to_fine_tuned_model,
#      30     # Finetuning HPs
#      31     time_limit=60,
#      32     finetuning_config={"learning_rate": 0.00001, "batch_size": 1, "max_steps": 100},
#      33     validation_metric="log_loss",
#      34     # Input Data
#      35     X_train=pd.DataFrame(X_train),
#      36     image_train=image_train,
#      37     y_train=pd.Series(y_train),
#      38     categorical_features_index=None,
#      39     device="cuda",  # use "cpu" if you don't have a GPU
#      40     task_type="multiclass",
#      41     # Optional
#      42     show_training_curve=False,  # Shows a final report after finetuning.
#      43     logger_level=0,  # Shows all logs, higher values shows less
#      44     freeze_input=True,  # Freeze the input layers (encoder and y_encoder) during finetuning
#      45     mixer_type='MGM' # MGM MGM+CQAM
#      46 )
#      48 # disables preprocessing at inference time to match fine-tuning
#      49 no_preprocessing_inference_config = ModelInterfaceConfig(
#      50     FINGERPRINT_FEATURE=False,
#      51     PREPROCESS_TRANSFORMS=[PreprocessorConfig(name='none')]
#      52 )
#
# File ~/works/research/MultiModalPFN/mmpfn/scripts_finetune_mm/finetune_tabpfn_main.py:392, in fine_tune_tabpfn(mixer_type, path_to_base_model, save_path_to_fine_tuned_model, time_limit, finetuning_config, validation_metric, categorical_features_index, task_type, device, y_train, X_train, image_train, use_multiple_gpus, multiple_device_ids, X_val, y_val, random_seed, logger_level, show_training_curve, freeze_input)
#     390 model.train()
#     391 optimizer.train()
# --> 392 step_results = _fine_tune_step(
#     393     batch_X_train=batch_data["X_train"] if "X_train" in batch_data.keys() else None,
#     394     batch_X_test=batch_data["X_test"] if "X_test" in batch_data.keys() else None,
#     395     batch_X_image_train=batch_data["image_train"] if "image_train" in batch_data.keys() else None,
#     396     batch_X_image_test=batch_data["image_test"] if "image_test" in batch_data.keys() else None,
#     397     batch_y_train=batch_data["y_train"],
#     398     batch_y_test=batch_data["y_test"],
#     399     device=device,
#     400     optimizer=optimizer,
#     401     model_forward_fn=model_forward_fn,
#     402     loss_fn=fts.loss_fn,
#     403     gradient_accumulation_steps=gradient_accumulation_steps,
#     404     # Updated by the loop
#     405     model=model,
#     406     scaler=scaler,
#     407     step_with_update=update_now,
#     408 )
#     410 if step_results.optimizer_step_skipped:
#     411     logger.info("\nOptimizer step skipped due to NaNs/infs in grad scaling.")
#
# File ~/works/research/MultiModalPFN/mmpfn/scripts_finetune_mm/finetune_tabpfn_main.py:668, in _fine_tune_step(batch_X_train, batch_X_test, batch_X_image_train, batch_X_image_test, batch_y_train, batch_y_test, device, model, optimizer, model_forward_fn, loss_fn, scaler, step_with_update, gradient_accumulation_steps)
#     666 torch.cuda.empty_cache()
#     667 # Backward, Scaled for Mixed Precision
# --> 668 scaler.scale(loss).backward()
#     670 # Update
#     671 optimizer_step_skipped = False
#
# File ~/anaconda3/envs/mmpfn/lib/python3.10/site-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~/anaconda3/envs/mmpfn/lib/python3.10/site-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File ~/anaconda3/envs/mmpfn/lib/python3.10/site-packages/torch/autograd/graph.py:769, in _engine_run_backward(t_outputs, *args, **kwargs)
#     767     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     768 try:
# --> 769     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     770         t_outputs, *args, **kwargs
#     771     )  # Calls into the C++ engine to run the backward pass
#     772 finally:
#     773     if attach_logging_hooks:
#
# File ~/anaconda3/envs/mmpfn/lib/python3.10/site-packages/torch/utils/checkpoint.py:1116, in _checkpoint_hook.__init__.<locals>.unpack_hook(holder)
#    1112 try:
#    1113     with _recomputation_hook(
#    1114         weakref.ref(frame), gid
#    1115     ), torch.autograd.enable_grad():
# -> 1116         frame.recompute_fn(*args)
#    1117 except _StopRecomputationError:
#    1118     pass
#
# File ~/anaconda3/envs/mmpfn/lib/python3.10/site-packages/torch/utils/checkpoint.py:1400, in _checkpoint_without_reentrant_generator.<locals>.recompute_fn(*inputs)
#    1396 device_autocast_ctx = torch.amp.autocast(
#    1397     device_type=device, **device_autocast_kwargs
#    1398 ) if torch.amp.is_autocast_available(device) else contextlib.nullcontext()
#    1399 with device_autocast_ctx, torch.cpu.amp.autocast(**cpu_autocast_kwargs), recompute_context:  # type: ignore[attr-defined]
# -> 1400     fn(*args, **kwargs)
#
# File ~/anaconda3/envs/mmpfn/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/mmpfn/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/works/research/MultiModalPFN/mmpfn/models/mmpfn_v2/model/layer.py:449, in PerFeatureEncoderLayer.forward(self, state, single_eval_pos, cache_trainset_representation, att_src)
#     439     raise AssertionError(
#     440         "Pre-norm implementation is wrong, as the residual should never"
#     441         " be layer normed here.",
#     442     )
#     443     state = layer_norm(
#     444         state,
#     445         allow_inplace=True,
#     446         save_peak_mem_factor=save_peak_mem_factor,
#     447     )
# --> 449 state = sublayer(state)
#     450 if not self.pre_norm:
#     451     state = layer_norm(
#     452         state,
#     453         allow_inplace=True,
#     454         save_peak_mem_factor=save_peak_mem_factor,
#     455     )
#
# File ~/anaconda3/envs/mmpfn/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/mmpfn/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/works/research/MultiModalPFN/mmpfn/models/mmpfn_v2/model/mlp.py:132, in MLP.forward(self, x, add_input, allow_inplace, save_peak_mem_factor)
#     130 input_shape = x.shape
#     131 x = x.reshape(-1, x.size(-1))
# --> 132 x = self._compute(
#     133     x,
#     134     add_input=add_input,
#     135     allow_inplace=allow_inplace,
#     136     save_peak_mem_factor=save_peak_mem_factor,
#     137 )
#     138 return x.reshape(input_shape)
#
# File ~/works/research/MultiModalPFN/mmpfn/models/mmpfn_v2/model/memory.py:100, in support_save_peak_mem_factor.<locals>.method_(self, x, add_input, allow_inplace, save_peak_mem_factor, *args, **kwargs)
#      97     return x
#      99 if add_input:
# --> 100     return x + method(self, x, *args, **kwargs)
#     102 return method(self, x, *args, **kwargs)
#
# File ~/works/research/MultiModalPFN/mmpfn/models/mmpfn_v2/model/mlp.py:97, in MLP._compute(self, x)
#      95 x = self.linear1(x)
#      96 if self.activation is Activation.GELU:
# ---> 97     x = torch.nn.functional.gelu(x)
#      98 elif self.activation is Activation.RELU:
#      99     x = torch.nn.functional.relu(x)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 3.51 GiB. GPU 0 has a total capacity of 12.00 GiB of which 0 bytes is free. Of the allocated memory 32.30 GiB is allocated by PyTorch, and 291.77 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
# get mean and std of accuracy scores
mean_accuracy = np.mean(accuracy_scores)
std_accuracy = np.std(accuracy_scores)
print("Mean Accuracy:", mean_accuracy)
print("Std Accuracy:", std_accuracy)
# Out:
# Mean Accuracy: 0.8203225806451613
# Std Accuracy: 0.026836305723603966
