# %%
import pandas as pd

# %%
train = pd.read_csv('data/cbis_ddsm/csv/calc_case_description_train_set.csv')

# %%
train[['image file path', 'cropped image file path', 'ROI mask file path']].isna().sum()
# Out:
# image file path            0
# cropped image file path    0
# ROI mask file path         0
# dtype: int64

# %%
test = pd.read_csv('data/cbis_ddsm/csv/calc_case_description_test_set.csv')
test[['image file path', 'cropped image file path', 'ROI mask file path']].isna().sum()
# Out:
# image file path            0
# cropped image file path    0
# ROI mask file path         0
# dtype: int64
